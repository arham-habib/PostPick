# %%
import pandas as pd

# %%
games = pd.read_csv("../../data/ncaab/game/ncaab_2025_men_d1.csv")
games.head()

# %%
filtered_games = games[games.finalMessage == "FINAL"]
filtered_games.head()

# %%
filtered_games.loc[:, ['home_score', 'away_score']].corr()

# %%
FDU_GAMES = games[(games.home_team == "FDU") | (games.away_team == "FDU")]
FDU_GAMES.head()

# %%
FDU_GAMES.loc[:, ['home_score', 'away_score']].std()

# %%
FDU_GAMES.loc[:, ['home_score', 'away_score']].mean()
